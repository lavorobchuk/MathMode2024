# %% [markdown]
# # Библиотека PANDAS
# ### Выполнила Воробчук Лилия Андреевна НММбд-01-22

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В каждом разделе вам предлагается выполнить несколько заданий. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотекам pandas и matplotlib.
#
# ### Оценивание и штрафы
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написаем production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.
#
# ### Формат сдачи
# Для сдачи задания получившийся файл \*.ipynb с решением необходимо выложить в свой репозиторий github.

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных. С этой библиотекой мы сейчас и познакомимся.
#
# Основной объект в pandas это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# %pylab inline  
# import almost all we need
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Данные находятся в приложенном файле `chipotle.tsv`

# %% [markdown]
# #### 1. Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы?

# %%
df = pd.read_csv('chipotle.tsv', sep='\t')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# В таблице 4622 строки и 6 столбцов:
# 1) Индекс
# 2) order_id
# 3) quantity
# 4) item_name
# 5) choice_description
# 6) item_price

# %% [markdown]
# #### 2.  Ответьте на вопросы:
# 1. Сколько заказов попало в выборку?
# 2. Сколько уникальных категорий товара было куплено? (item_name)

# %%
df['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# 1) В выборку попало 1834 заказа
# 2) 50 уникальных категорий товаров было куплено

# %% [markdown]
# #### 3. Есть ли в данных пропуски? В каких колонках?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %% [markdown]
# Пропуски есть только в колонке choice_description

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых.

# %%
df = df.fillna(' ')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                           $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                           $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# #### 4. Посмотрите внимательнее на колонку с ценой товара. Какого она типа? Создайте новую колонку так, чтобы в ней цена была числом.
#
# Для этого попробуйте применить функцию-преобразование к каждой строке вашей таблицы (для этого есть соответствующая функция).

# %%
df['item_price_float'] = df['item_price'].apply(lambda s: float(s.strip()[1:]))
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                                        $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                        $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
#
#    item_price_float
# 0              2.39
# 1              3.39
# 2              3.39
# 3              2.39
# 4             16.98

# %%
df.info() # колонка была типа object (строка), создали новую колонку, чтобы цена была числом
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  4622 non-null   object
#  4   item_price          4622 non-null   object
#  5   item_price_float    4622 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 216.8+ KB

# %% [markdown]
# Какая средняя/минимальная/максимальная цена у товара?

# %%
print("Средняя цена товара: ", '%.2f' % (df['item_price_float']/df['quantity']).mean())
print("Минимальная цена товара: ", (df['item_price_float']/df['quantity']).min())
print("Максимальная цена товара: ", (df['item_price_float']/df['quantity']).max())
# Out:
# Средняя цена товара:  7.08
# Минимальная цена товара:  1.09
# Максимальная цена товара:  11.89

# %% [markdown]
# Удалите старую колонку с ценой.

# %%
df_dropped = df.drop(labels = 'item_price', axis = 1)
df_dropped
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price_float
# 0                                                                    2.39
# 1                                          [Clementine]              3.39
# 2                                               [Apple]              3.39
# 3                                                                    2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98
# ...                                                 ...               ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...             11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...             11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...             11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...              8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...              8.75
#
# [4622 rows x 5 columns]

# %% [markdown]
# #### 5. Какие 5 товаров были самыми дешёвыми и самыми дорогими? (по item_name)
#
# Для этого будет удобно избавиться от дубликатов и отсортировать товары. Не забудьте про количество товара.

# %%
df_no_duplicates = df_dropped.drop_duplicates('item_name')
df_no_duplicates.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price_float
# 0                                                                 2.39
# 1                                       [Clementine]              3.39
# 2                                            [Apple]              3.39
# 3                                                                 2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98

# %%
df_no_duplicates['singular_item_price'] = df_no_duplicates['item_price_float'] / df_no_duplicates['quantity']
df_no_duplicates.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price_float  \
# 0                                                                 2.39
# 1                                       [Clementine]              3.39
# 2                                            [Apple]              3.39
# 3                                                                 2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98
#
#    singular_item_price
# 0                 2.39
# 1                 3.39
# 2                 3.39
# 3                 2.39
# 4                 8.49

# %%
df_sorted = df_no_duplicates.sort_values('singular_item_price', axis=0)
df_sorted.head()
# Out:
#      order_id  quantity          item_name choice_description  \
# 34         17         1      Bottled Water
# 18          9         2        Canned Soda           [Sprite]
# 263       114         1  Canned Soft Drink             [Coke]
# 6           3         1      Side of Chips
# 40         19         1              Chips
#
#      item_price_float  singular_item_price
# 34               1.09                 1.09
# 18               2.18                 1.09
# 263              1.25                 1.25
# 6                1.69                 1.69
# 40               2.15                 2.15

# %%
df_sorted[['item_name', 'choice_description', 'singular_item_price']].tail() # 5 самых дорогих товаров
# Out:
#                   item_name  \
# 7             Steak Burrito
# 168   Barbacoa Crispy Tacos
# 1132    Carnitas Salad Bowl
# 1229    Barbacoa Salad Bowl
# 281        Steak Salad Bowl
#
#                                      choice_description  singular_item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...                11.75
# 168   [Tomatillo Red Chili Salsa, [Rice, Black Beans...                11.75
# 1132  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...                11.89
# 1229  [Fresh Tomato Salsa, [Rice, Fajita Vegetables,...                11.89
# 281   [Tomatillo Red Chili Salsa, [Black Beans, Chee...                11.89

# %%
df_sorted[['item_name', 'choice_description', 'singular_item_price']].head() # 5 самых дешёвых товаров
# Out:
#              item_name choice_description  singular_item_price
# 34       Bottled Water                                    1.09
# 18         Canned Soda           [Sprite]                 1.09
# 263  Canned Soft Drink             [Coke]                 1.25
# 6        Side of Chips                                    1.69
# 40               Chips                                    2.15

# %% [markdown]
# #### 6. Сколько раз клиенты покупали больше 1 Chicken Bowl (item_name)?

# %%
print("Клиенты покупали Chicken Bowl (> 1 раза)", \
      len(df[(df['quantity'] > 1) & (df['item_name'] == 'Chicken Bowl')]), "раза!")
# Out:
# Клиенты покупали Chicken Bowl (> 1 раза) 33 раза!

# %% [markdown]
# #### 7. Какой средний чек у заказа? Сколько в среднем товаров покупают?
#
# Если необходимо провести вычисления в терминах заказов, то будет удобно сгруппировать строки по заказам и посчитать необходимые статистики.

# %%
print("Средний чек у заказа -", '%.2f' % (df.groupby(by='order_id')['item_price_float'].sum()).mean(), "долларов!")
# Out:
# Средний чек у заказа - 18.81 долларов!

# %%
print("В среднем покупают", '%.2f' % (df.groupby(by='order_id')['quantity'].sum()).mean(), "товаров!")
# Out:
# В среднем покупают 2.71 товаров!

# %% [markdown]
# #### 8. Сколько заказов содержали ровно 1 товар?

# %%
print((df.groupby(by='order_id')['quantity'].sum() == 1).sum(), "заказов содержали ровно 1 товар!")
# Out:
# 56 заказов содержали ровно 1 товар!

# %% [markdown]
# #### 9. Какая самая популярная категория товара?

# %%
df_pop = df.groupby(by='item_name')['quantity'].sum()
df_pop_sorted = df_pop.sort_values(ascending=False)
df_pop_sorted.nlargest(10)
# Out:
# item_name
# Chicken Bowl                    761
# Chicken Burrito                 591
# Chips and Guacamole             506
# Steak Burrito                   386
# Canned Soft Drink               351
# Chips                           230
# Steak Bowl                      221
# Bottled Water                   211
# Chips and Fresh Tomato Salsa    130
# Canned Soda                     126
# Name: quantity, dtype: int64

# %% [markdown]
# Самая популярная категория товара - Chicken Bowl!

# %% [markdown]
# #### 10. Какие виды Burrito существуют? Какой из них чаще всего покупают? Какой из них самый дорогой?

# %%
df['is_burrito'] = df['item_name'].apply(lambda s: "Burrito" in s)
df.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
#       item_price_float  is_burrito
# 4617             11.75        True
# 4618             11.75        True
# 4619             11.25       False
# 4620              8.75       False
# 4621              8.75       False

# %%
df_no_duplicates = df.drop_duplicates('item_name')
df_burrito_no_duplicates = df_no_duplicates[df_no_duplicates['is_burrito'] == True]
df_burrito_no_duplicates
# Out:
#      order_id  quantity         item_name  \
# 7           4         1     Steak Burrito
# 16          8         1   Chicken Burrito
# 21         11         1  Barbacoa Burrito
# 27         14         1  Carnitas Burrito
# 57         26         1    Veggie Burrito
# 510       214         1           Burrito
#
#                                     choice_description item_price  \
# 7    [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 16   [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 21   [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...     $8.99
# 27   [[Tomatillo-Green Chili Salsa (Medium), Roaste...     $8.99
# 57   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.25
# 510  [Adobo-Marinated and Grilled Chicken, Pinto Be...     $7.40
#
#      item_price_float  is_burrito
# 7               11.75        True
# 16               8.49        True
# 21               8.99        True
# 27               8.99        True
# 57              11.25        True
# 510              7.40        True

# %%
df_burrito = df[df['is_burrito'] == True]
df_burrito # тут только буррито!
# Out:
#       order_id  quantity         item_name  \
# 7            4         1     Steak Burrito
# 9            5         1     Steak Burrito
# 16           8         1   Chicken Burrito
# 17           9         1   Chicken Burrito
# 21          11         1  Barbacoa Burrito
# ...        ...       ...               ...
# 4608      1829         1    Veggie Burrito
# 4610      1830         1     Steak Burrito
# 4611      1830         1    Veggie Burrito
# 4617      1833         1     Steak Burrito
# 4618      1833         1     Steak Burrito
#
#                                      choice_description item_price  \
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 16    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 17    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.49
# 21    [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...     $8.99
# ...                                                 ...        ...
# 4608  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.25
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4611  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...    $11.25
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
#
#       item_price_float  is_burrito
# 7                11.75        True
# 9                 9.25        True
# 16                8.49        True
# 17                8.49        True
# 21                8.99        True
# ...                ...         ...
# 4608             11.25        True
# 4610             11.75        True
# 4611             11.25        True
# 4617             11.75        True
# 4618             11.75        True
#
# [1172 rows x 7 columns]

# %% [markdown]
# Существуют 6 видов Burrito: Steak, Chicken, Barbacoa, Carnitas, Veggie and just Burrito.

# %%
(df_burrito.groupby(by='item_name')['quantity'].sum()).sort_values(ascending=False)
# Out:
# item_name
# Chicken Burrito     591
# Steak Burrito       386
# Veggie Burrito       97
# Barbacoa Burrito     91
# Carnitas Burrito     60
# Burrito               6
# Name: quantity, dtype: int64

# %% [markdown]
# Чаще всего покупают **Chicken Burrito**!

# %%
df_burrito.sort_values('item_price_float', axis=0)
# Out:
#       order_id  quantity        item_name  \
# 760        313         1          Burrito
# 510        214         1          Burrito
# 511        214         1          Burrito
# 519        217         1          Burrito
# 759        313         1          Burrito
# ...        ...       ...              ...
# 3603      1443         3    Steak Burrito
# 1255       511         3    Steak Burrito
# 3601      1443         3   Veggie Burrito
# 1254       511         4  Chicken Burrito
# 3602      1443         4  Chicken Burrito
#
#                                      choice_description item_price  \
# 760   [White Rice, Adobo-Marinated and Grilled Steak...     $7.40
# 510   [Adobo-Marinated and Grilled Chicken, Pinto Be...     $7.40
# 511   [Braised Barbacoa, Vegetarian Black Beans, [So...     $7.40
# 519   [Braised Barbacoa, Pinto Beans, [Sour Cream, S...     $7.40
# 759   [White Rice, Adobo-Marinated and Grilled Steak...     $7.40
# ...                                                 ...        ...
# 3603  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $27.75
# 1255  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $27.75
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $33.75
# 1254  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $35.00
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $35.00
#
#       item_price_float  is_burrito
# 760               7.40        True
# 510               7.40        True
# 511               7.40        True
# 519               7.40        True
# 759               7.40        True
# ...                ...         ...
# 3603             27.75        True
# 1255             27.75        True
# 3601             33.75        True
# 1254             35.00        True
# 3602             35.00        True
#
# [1172 rows x 7 columns]

# %% [markdown]
# Самый дорогой вид Burrito - **Steak Burrito**

# %% [markdown]
# #### 11. В каком количестве заказов есть товар, который стоит более 40% от суммы всего чека?
#
# Возможно, будет удобно посчитать отдельно среднюю стоимость заказа, добавить ее в исходные данные и сделать необходимые проверки.
#
# *Данный комментарий стоит воспринимать как подсказку к одному из вариантов решений задания. Если в вашем варианте решения он не нужнен, это не страшно*

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price  \
# 0                                                        $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                        $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                        $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
#
#    item_price_float  is_burrito
# 0              2.39       False
# 1              3.39       False
# 2              3.39       False
# 3              2.39       False
# 4             16.98       False
# 5             10.98       False
# 6              1.69       False
# 7             11.75        True
# 8              9.25       False
# 9              9.25        True

# %%
df['check_sum'] = df.groupby('order_id')['item_price_float'].transform(lambda p: p.sum()) 
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price  \
# 0                                                        $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                        $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                        $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
#
#    item_price_float  is_burrito  check_sum
# 0              2.39       False      11.56
# 1              3.39       False      11.56
# 2              3.39       False      11.56
# 3              2.39       False      11.56
# 4             16.98       False      16.98
# 5             10.98       False      12.67
# 6              1.69       False      12.67
# 7             11.75        True      21.00
# 8              9.25       False      21.00
# 9              9.25        True      13.70

# %%
df_short_ver = df.drop(labels = {'item_price', 'choice_description', 'is_burrito'}, axis = 1)
df_short_ver.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#    item_price_float  check_sum
# 0              2.39      11.56
# 1              3.39      11.56
# 2              3.39      11.56
# 3              2.39      11.56
# 4             16.98      16.98

# %%
df_short_ver['singular_item_price'] = df['item_price_float'] / df['quantity']
df_short_ver.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#    item_price_float  check_sum  singular_item_price
# 0              2.39      11.56                 2.39
# 1              3.39      11.56                 3.39
# 2              3.39      11.56                 3.39
# 3              2.39      11.56                 2.39
# 4             16.98      16.98                 8.49

# %%
df_short_ver['percentage'] = (df_short_ver['singular_item_price'] / df_short_ver['check_sum']) * 100
df_short_ver.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#    item_price_float  check_sum  singular_item_price  percentage
# 0              2.39      11.56                 2.39    20.67474
# 1              3.39      11.56                 3.39    29.32526
# 2              3.39      11.56                 3.39    29.32526
# 3              2.39      11.56                 2.39    20.67474
# 4             16.98      16.98                 8.49    50.00000

# %%
df_short_ver['greater_than_40'] = df_short_ver['percentage'] > 40
df_short_ver
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#       item_price_float  check_sum  singular_item_price  percentage  \
# 0                 2.39      11.56                 2.39   20.674740
# 1                 3.39      11.56                 3.39   29.325260
# 2                 3.39      11.56                 3.39   29.325260
# 3                 2.39      11.56                 2.39   20.674740
# 4                16.98      16.98                 8.49   50.000000
# ...                ...        ...                  ...         ...
# 4617             11.75      23.50                11.75   50.000000
# 4618             11.75      23.50                11.75   50.000000
# 4619             11.25      28.75                11.25   39.130435
# 4620              8.75      28.75                 8.75   30.434783
# 4621              8.75      28.75                 8.75   30.434783
#
#       greater_than_40
# 0               False
# 1               False
# 2               False
# 3               False
# 4                True
# ...               ...
# 4617             True
# 4618             True
# 4619            False
# 4620            False
# 4621            False
#
# [4622 rows x 8 columns]

# %%
print("В", (df_short_ver.groupby(by='order_id')['greater_than_40'].sum() > 0).sum(), \
     "заказах есть товар, который стоит более 40% от суммы всего чека")
# Out:
# В 1589 заказах есть товар, который стоит более 40% от суммы всего чека

# %% [markdown]
# #### 12. Предположим, что в данных была ошибка и Diet Coke (choice_description), который стоил $1.25, должен был стоить 1.35. Скорректируйте данные в таблицы и посчитайте, на какой процент больше денег было заработано с этого товара. Не забывайте, что количество товара не всегда равно 1.

# %%
df = df.drop(labels = {'item_price', 'is_burrito', 'check_sum'}, axis = 1)
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price_float
# 0                                                                    2.39
# 1                                          [Clementine]              3.39
# 2                                               [Apple]              3.39
# 3                                                                    2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98
# ...                                                 ...               ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...             11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...             11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...             11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...              8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...              8.75
#
# [4622 rows x 5 columns]

# %%
revenue_b = df[(df['item_name'] == 'Canned Soft Drink') & (df['choice_description'] == '[Diet Coke]')]['item_price_float'].sum()
print("Долларов заработано с этого товара до изменения цены:", revenue_b)
# Out:
# Долларов заработано с этого товара до изменения цены: 143.75

# %%
df.loc[df['choice_description'] == '[Diet Coke]', 'item_price_float'] += 0.1 * df['quantity']

# %%
df.head(495) # проверили, что работает правильно даже при количестве, равном 2
# Out:
#      order_id  quantity                              item_name  \
# 0           1         1           Chips and Fresh Tomato Salsa
# 1           1         1                                   Izze
# 2           1         1                       Nantucket Nectar
# 3           1         1  Chips and Tomatillo-Green Chili Salsa
# 4           2         2                           Chicken Bowl
# ..        ...       ...                                    ...
# 490       206         1                           Chicken Bowl
# 491       206         1                             Steak Bowl
# 492       206         2                      Canned Soft Drink
# 493       206         1                    Chips and Guacamole
# 494       207         1                       Steak Soft Tacos
#
#                                     choice_description  item_price_float
# 0                                                                   2.39
# 1                                         [Clementine]              3.39
# 2                                              [Apple]              3.39
# 3                                                                   2.39
# 4    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98
# ..                                                 ...               ...
# 490  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...             11.25
# 491  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...             11.75
# 492                                        [Diet Coke]              2.70
# 493                                                                 4.45
# 494         [Fresh Tomato Salsa, [Sour Cream, Cheese]]              9.25
#
# [495 rows x 5 columns]

# %%
revenue_a = df[(df['item_name'] == 'Canned Soft Drink') & (df['choice_description'] == '[Diet Coke]')]['item_price_float'].sum()
print("Долларов заработано с этого товара после изменения цены:", '%.2f' % revenue_a)
# Out:
# Долларов заработано с этого товара после изменения цены: 155.25

# %%
percent = int(float('%.2f' % (revenue_a / revenue_b - 1)) * 100)
print("С учётом изменения цены на этот товар удалось бы заработать на", percent, "больше!")
# Out:
# С учётом изменения цены на этот товар удалось бы заработать на 8 больше!

# %% [markdown]
# #### 13. Создайте новый DateFrame из матрицы, созданной ниже. Назовите колонки index, column1, column2 и сделайте первую колонку индексом.

# %%
data = [[1, 'A', 'X'],
        [2, 'B', 'Y'],
        [3, 'C', 'Z']]

data_df = pd.DataFrame(data, columns=['index', 'column1', 'column2'])
data_df.set_index('index', inplace=True)
data_df
# Out:
#       column1 column2
# index
# 1           A       X
# 2           B       Y
# 3           C       Z

# %% [markdown]
# Сохраните DataFrame на диск в формате csv без индексов и названий столбцов.

# %%
data_df.to_csv('data.csv', index=False, header=False)

# %% [markdown]
# ## 2. Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. В этом разделе мы этим и займёмся.
#
# У matplotlib, конечно, же есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторое величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить каждый из них. Не менее важно усвоить базовые принципы визуализаций:
# - на графиках должны быть подписаны оси;
# - у визуализации должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах).
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import datetime

start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2018, 1, 31)
delta_seconds = int((end - start).total_seconds())

dates = pd.DataFrame(index = df['order_id'].unique())

dates['date'] = [
    (start + datetime.timedelta(seconds=random.randint(0, delta_seconds))).strftime('%Y-%m-%d') # преобразует в строки
    for _ in range(df['order_id'].nunique())] # даты распределены случайным образом

# если DataFrame с покупками из прошлого заказа называется не df, замените на ваше название ниже
df['date'] = df['order_id'].map(dates['date'])

# %% [markdown]
# #### 14. Постройте гистограмму распределения сумм покупок и гистограмму средних цен отдельных видов продуктов item_name.
#
# Изображайте на двух соседних графиках. Для этого может быть полезен subplot.

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price_float  \
# 0                                                                    2.39
# 1                                          [Clementine]              3.39
# 2                                               [Apple]              3.39
# 3                                                                    2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98
# ...                                                 ...               ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...             11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...             11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...             11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...              8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...              8.75
#
#             date
# 0     2018-01-30
# 1     2018-01-30
# 2     2018-01-30
# 3     2018-01-30
# 4     2018-01-01
# ...          ...
# 4617  2018-01-09
# 4618  2018-01-09
# 4619  2018-01-09
# 4620  2018-01-09
# 4621  2018-01-09
#
# [4622 rows x 6 columns]

# %%
df['check_sum'] = df.groupby('order_id')['item_price_float'].transform(lambda p: p.sum())
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price_float  \
# 0                                                                    2.39
# 1                                          [Clementine]              3.39
# 2                                               [Apple]              3.39
# 3                                                                    2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98
# ...                                                 ...               ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...             11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...             11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...             11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...              8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...              8.75
#
#             date  check_sum
# 0     2018-01-30      11.56
# 1     2018-01-30      11.56
# 2     2018-01-30      11.56
# 3     2018-01-30      11.56
# 4     2018-01-01      16.98
# ...          ...        ...
# 4617  2018-01-09      23.50
# 4618  2018-01-09      23.50
# 4619  2018-01-09      28.75
# 4620  2018-01-09      28.75
# 4621  2018-01-09      28.75
#
# [4622 rows x 7 columns]

# %%
df_14 = df.drop_duplicates('order_id')
df_14
# Out:
#       order_id  quantity                     item_name  \
# 0            1         1  Chips and Fresh Tomato Salsa
# 4            2         2                  Chicken Bowl
# 5            3         1                  Chicken Bowl
# 7            4         1                 Steak Burrito
# 9            5         1                 Steak Burrito
# ...        ...       ...                           ...
# 4610      1830         1                 Steak Burrito
# 4612      1831         1                 Carnitas Bowl
# 4615      1832         1            Chicken Soft Tacos
# 4617      1833         1                 Steak Burrito
# 4619      1834         1            Chicken Salad Bowl
#
#                                      choice_description  item_price_float  \
# 0                                                                    2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...             10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...             11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...              9.25
# ...                                                 ...               ...
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...             11.75
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...              9.25
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]              8.75
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...             11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...             11.25
#
#             date  check_sum
# 0     2018-01-30      11.56
# 4     2018-01-01      16.98
# 5     2018-01-10      12.67
# 7     2018-01-22      21.00
# 9     2018-01-21      13.70
# ...          ...        ...
# 4610  2018-01-26      23.00
# 4612  2018-01-13      12.90
# 4615  2018-01-30      13.20
# 4617  2018-01-09      23.50
# 4619  2018-01-09      28.75
#
# [1834 rows x 7 columns]

# %%
df_14_1 = df.drop_duplicates('item_name')
df_14_1 = df_14_1.drop('choice_description', axis = 1)
df_14_1['singular_item_price'] = df_12_1['item_price_float'] / df_12_1['quantity']
df_14_1.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#    item_price_float        date  check_sum  singular_item_price
# 0              2.39  2018-01-30      11.56                 2.39
# 1              3.39  2018-01-30      11.56                 3.39
# 2              3.39  2018-01-30      11.56                 3.39
# 3              2.39  2018-01-30      11.56                 2.39
# 4             16.98  2018-01-01      16.98                 8.49

# %%
plt.figure(figsize=(8, 6))
plt.bar(df_14_1['item_name'], df_14_1['singular_item_price'], color='lightgreen')
plt.xlabel('Название продукта')
plt.xticks(rotation=45, fontsize=1)
plt.ylabel('Цена единицы продукта')
plt.title('Гистограмма средних цен продуктов')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Все продукты плохо влезают, поэтому я выбрал 10 первых попавшихся в датафрейме.

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(df_14['check_sum'], bins=100, color='green', edgecolor='black')
plt.xlabel('Сумма покупки')
plt.ylabel('Частота')
plt.title('Распределение сумм покупок')

plt.subplot(1, 2, 2)
plt.bar(df_14_1['item_name'][:10], df_14_1['singular_item_price'][:10], color='lightgreen')
plt.xlabel('Название продукта')
plt.xticks(rotation=45, fontsize = 6)
plt.ylabel('Цена единицы продукта')
plt.title('Гистограмма средних цен продуктов')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 15. Постройте график зависимости суммы покупок от дней.

# %%
df_15 = df_14
df_15.head()
# Out:
#    order_id  quantity                     item_name  \
# 0         1         1  Chips and Fresh Tomato Salsa
# 4         2         2                  Chicken Bowl
# 5         3         1                  Chicken Bowl
# 7         4         1                 Steak Burrito
# 9         5         1                 Steak Burrito
#
#                                   choice_description  item_price_float  \
# 0                                                                 2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...             10.98
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...             11.75
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...              9.25
#
#          date  check_sum
# 0  2018-01-30      11.56
# 4  2018-01-01      16.98
# 5  2018-01-10      12.67
# 7  2018-01-22      21.00
# 9  2018-01-21      13.70

# %%
df_15['daily_rev'] = df_15.groupby('date')['check_sum'].transform(lambda p: p.sum()) # нашли полную прибыль за каждый день
df_15.head()
# Out:
#    order_id  quantity                     item_name  \
# 0         1         1  Chips and Fresh Tomato Salsa
# 4         2         2                  Chicken Bowl
# 5         3         1                  Chicken Bowl
# 7         4         1                 Steak Burrito
# 9         5         1                 Steak Burrito
#
#                                   choice_description  item_price_float  \
# 0                                                                 2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...             10.98
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...             11.75
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...              9.25
#
#          date  check_sum  daily_rev
# 0  2018-01-30      11.56    1278.04
# 4  2018-01-01      16.98    1253.63
# 5  2018-01-10      12.67    1002.51
# 7  2018-01-22      21.00    1552.04
# 9  2018-01-21      13.70    1371.42

# %%
df_15 = df_15.drop_duplicates('date')
df_15.head()
# Out:
#    order_id  quantity                     item_name  \
# 0         1         1  Chips and Fresh Tomato Salsa
# 4         2         2                  Chicken Bowl
# 5         3         1                  Chicken Bowl
# 7         4         1                 Steak Burrito
# 9         5         1                 Steak Burrito
#
#                                   choice_description  item_price_float  \
# 0                                                                 2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...             16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...             10.98
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...             11.75
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...              9.25
#
#          date  check_sum  daily_rev
# 0  2018-01-30      11.56    1278.04
# 4  2018-01-01      16.98    1253.63
# 5  2018-01-10      12.67    1002.51
# 7  2018-01-22      21.00    1552.04
# 9  2018-01-21      13.70    1371.42

# %%
df_15['day'] = df['date'].apply(lambda s: int(s[8::]))
df_15 = df_15.sort_values('day', axis=0)
df_15 = df_15.drop('choice_description', axis = 1)
df_15.head()
# Out:
#      order_id  quantity        item_name  item_price_float        date  \
# 4           2         2     Chicken Bowl             16.98  2018-01-01
# 83         37         1  Chicken Burrito              8.75  2018-01-02
# 134        59         1  Chicken Burrito             10.98  2018-01-03
# 195        87         1      Canned Soda              1.09  2018-01-04
# 13          7         1     Chicken Bowl             11.25  2018-01-05
#
#      check_sum  daily_rev  day
# 4        16.98    1253.63    1
# 83       18.00    1000.98    2
# 134      10.98    1253.05    3
# 195      10.08    1143.43    4
# 13       15.70    1415.29    5

# %%
plt.figure(figsize=(8, 6))

plt.bar(df_15['day'], df_15['daily_rev'], color='lightblue')
plt.xlabel('День')
plt.ylabel('Ежедневная выручка')
plt.title('График зависимости суммы покупок от дней')

plt.show()

# %% [markdown]
# #### 16. Постройте средних сумм покупок по дням недели (bar plot).

# %%
df_16 = df
df_16['day'] = df['date'].apply(lambda s: int(s[8::]))
df_16 = df_16.sort_values('day', axis=0)
df_16 = df_16.drop('choice_description', axis = 1)
df_16.head()
# Out:
#       order_id  quantity                     item_name  item_price_float  \
# 3947      1582         1  Chips and Fresh Tomato Salsa              2.95
# 2707      1074         1              Barbacoa Burrito              9.25
# 3766      1508         1             6 Pack Soft Drink              6.49
# 2706      1074         1                         Chips              2.15
# 315        137         2            Chicken Salad Bowl             17.50
#
#             date  check_sum  day
# 3947  2018-01-01      12.20    1
# 2707  2018-01-01      22.30    1
# 3766  2018-01-01      18.24    1
# 2706  2018-01-01      22.30    1
# 315   2018-01-01      17.50    1

# %% [markdown]
# Первое января 2018 года был понедельником. Отталкиваемся от этого.

# %%
df_16['mod'] = df_16['day'] % 7
df_16.head()
# Out:
#       order_id  quantity                     item_name  item_price_float  \
# 3947      1582         1  Chips and Fresh Tomato Salsa              2.95
# 2707      1074         1              Barbacoa Burrito              9.25
# 3766      1508         1             6 Pack Soft Drink              6.49
# 2706      1074         1                         Chips              2.15
# 315        137         2            Chicken Salad Bowl             17.50
#
#             date  check_sum  day  mod
# 3947  2018-01-01      12.20    1    1
# 2707  2018-01-01      22.30    1    1
# 3766  2018-01-01      18.24    1    1
# 2706  2018-01-01      22.30    1    1
# 315   2018-01-01      17.50    1    1

# %%
# Создаем словарь для соответствия номера дня недели его названию
days_dict = {1: 'Понедельник', 2: 'Вторник', 3: 'Среда', 4: 'Четверг', 5: 'Пятница', 6: 'Суббота', 0: 'Воскресенье'}

# Добавляем новый столбец с названием дня
df_16['day_name'] = df_16['mod'].map(days_dict)
df_16.head()
# Out:
#       order_id  quantity                     item_name  item_price_float  \
# 3947      1582         1  Chips and Fresh Tomato Salsa              2.95
# 2707      1074         1              Barbacoa Burrito              9.25
# 3766      1508         1             6 Pack Soft Drink              6.49
# 2706      1074         1                         Chips              2.15
# 315        137         2            Chicken Salad Bowl             17.50
#
#             date  check_sum  day  mod     day_name
# 3947  2018-01-01      12.20    1    1  Понедельник
# 2707  2018-01-01      22.30    1    1  Понедельник
# 3766  2018-01-01      18.24    1    1  Понедельник
# 2706  2018-01-01      22.30    1    1  Понедельник
# 315   2018-01-01      17.50    1    1  Понедельник

# %%
mean_check_sum = df_16.groupby('day_name')['check_sum'].mean()
df_16 = df_16.merge(mean_check_sum, on='day_name', suffixes=('', '_mean'))
df_16
# Out:
#       order_id  quantity                     item_name  item_price_float  \
# 0         1582         1  Chips and Fresh Tomato Salsa              2.95
# 1         1074         1              Barbacoa Burrito              9.25
# 2         1508         1             6 Pack Soft Drink              6.49
# 3         1074         1                         Chips              2.15
# 4          137         2            Chicken Salad Bowl             17.50
# ...        ...       ...                           ...               ...
# 4617       364         1                  Chicken Bowl              8.75
# 4618       364         1           Chips and Guacamole              4.45
# 4619       705         1                 Barbacoa Bowl             11.75
# 4620       351         1           Chips and Guacamole              4.45
# 4621      1388         1                  Chicken Bowl             11.25
#
#             date  check_sum  day  mod     day_name  check_sum_mean
# 0     2018-01-01      12.20    1    1  Понедельник       23.922943
# 1     2018-01-01      22.30    1    1  Понедельник       23.922943
# 2     2018-01-01      18.24    1    1  Понедельник       23.922943
# 3     2018-01-01      22.30    1    1  Понедельник       23.922943
# 4     2018-01-01      17.50    1    1  Понедельник       23.922943
# ...          ...        ...  ...  ...          ...             ...
# 4617  2018-01-28      13.20   28    0  Воскресенье       26.796854
# 4618  2018-01-28      13.20   28    0  Воскресенье       26.796854
# 4619  2018-01-28      20.50   28    0  Воскресенье       26.796854
# 4620  2018-01-28      13.70   28    0  Воскресенье       26.796854
# 4621  2018-01-28      20.50   28    0  Воскресенье       26.796854
#
# [4622 rows x 10 columns]

# %%
df_16 = df_16.drop_duplicates('day_name')
df_16
# Out:
#       order_id  quantity                     item_name  item_price_float  \
# 0         1582         1  Chips and Fresh Tomato Salsa              2.95
# 768       1431         1               Chicken Burrito              8.75
# 1572      1826         1             Canned Soft Drink              1.25
# 2197      1732         1                         Chips              2.15
# 2834      1695         1                 Steak Burrito             11.75
# 3425      1055         1  Chips and Fresh Tomato Salsa              2.39
# 3980      1562         1                 Side of Chips              1.69
#
#             date  check_sum  day  mod     day_name  check_sum_mean
# 0     2018-01-01      12.20    1    1  Понедельник       23.922943
# 768   2018-01-02      41.60    2    2      Вторник       23.869776
# 1572  2018-01-03      15.95    3    3        Среда       22.213552
# 2197  2018-01-04      12.15    4    4      Четверг       20.286232
# 2834  2018-01-05      29.75    5    5      Пятница       22.312335
# 3425  2018-01-06      11.16    6    6      Суббота       22.381243
# 3980  2018-01-07      11.27    7    0  Воскресенье       26.796854

# %%
plt.figure(figsize=(8, 6))

plt.bar(df_16['day_name'], df_16['check_sum_mean'], color='lightgreen')
plt.xlabel('День недели')
plt.ylabel('Средняя сумма покупки')
plt.title('График средних сумм покупок по дням недели')

plt.show()

# %% [markdown]
# #### 17. Постройте график зависимости денег за товар от купленного количества (scatter plot).

# %%
df_17 = df
df_17 = df_17.drop('choice_description', axis = 1)
df_17
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#       item_price_float        date  check_sum  day
# 0                 2.39  2018-01-30      11.56   30
# 1                 3.39  2018-01-30      11.56   30
# 2                 3.39  2018-01-30      11.56   30
# 3                 2.39  2018-01-30      11.56   30
# 4                16.98  2018-01-01      16.98    1
# ...                ...         ...        ...  ...
# 4617             11.75  2018-01-09      23.50    9
# 4618             11.75  2018-01-09      23.50    9
# 4619             11.25  2018-01-09      28.75    9
# 4620              8.75  2018-01-09      28.75    9
# 4621              8.75  2018-01-09      28.75    9
#
# [4622 rows x 7 columns]

# %%
all_time_quantity = df_17.groupby('item_name')['quantity'].sum()
df_17 = df_17.merge(all_time_quantity, on='item_name')
df_17 = df_17.drop_duplicates('item_name')
df_17.head()
# Out:
#      order_id  quantity_x                              item_name  \
# 0           1           1           Chips and Fresh Tomato Salsa
# 110         1           1                                   Izze
# 130         1           1                       Nantucket Nectar
# 157         1           1  Chips and Tomatillo-Green Chili Salsa
# 188         2           2                           Chicken Bowl
#
#      item_price_float        date  check_sum  day  quantity_y
# 0                2.39  2018-01-30      11.56   30         130
# 110              3.39  2018-01-30      11.56   30          20
# 130              3.39  2018-01-30      11.56   30          29
# 157              2.39  2018-01-30      11.56   30          33
# 188             16.98  2018-01-01      16.98    1         761

# %%
df_17['singular_item_price'] = df_17['item_price_float'] / df_17['quantity_x']
df_17 = df_17.sort_values('singular_item_price', axis=0)
df_17.head()
# Out:
#       order_id  quantity_x          item_name  item_price_float        date  \
# 2954        17           1      Bottled Water              1.09  2018-01-10
# 2632         9           2        Canned Soda              2.18  2018-01-23
# 4163       114           1  Canned Soft Drink              1.25  2018-01-28
# 914          3           1      Side of Chips              1.69  2018-01-10
# 3225        19           1              Chips              2.15  2018-01-20
#
#       check_sum  day  quantity_y  singular_item_price
# 2954      10.08   10         211                 1.09
# 2632      10.67   23         126                 1.09
# 4163      13.00   28         351                 1.25
# 914       12.67   10         110                 1.69
# 3225      13.90   20         230                 2.15

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df_17['quantity_y'], df_17['singular_item_price'], color='b', marker='o')
plt.xlabel('Количество товара')
plt.ylabel('Деньги за товар')
plt.title('График зависимости денег за товар от купленного количества')

plt.grid(True)
plt.show()

# %% [markdown]
# #### 18. Сохраните график в формате pdf (так он останется векторизованным).

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df_17['quantity_y'], df_17['singular_item_price'], color='b', marker='o')
plt.xlabel('Количество товара')
plt.ylabel('Деньги за товар')
plt.title('График зависимости денег за товар от купленного количества')

plt.grid(True)

plt.savefig('scatter_plot.pdf', format='pdf')

plt.show()

# %% [markdown]
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
